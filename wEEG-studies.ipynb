# %% [markdown]
# # Wireless EEG systems
# Data, code and figures associated to **(Niso et al. 2020)**: Wireless EEG systems: applications and challenges.
#
# Submitted for publication. Preprint available at bioRxiv:
#
# This notebook contains some figures related to the use of wireless EEG (wEEG) systems in different applications in neuroscience.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Major ticks and minor ticks
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

# %%
# Open Googlesheet csv file
df = pd.read_csv('/Users/guiomar/Downloads/Data_Figures - Studies(1).csv')

# %%
#df
#df['Nchannels']
df.head()
# Out:
#   Area        Subarea  Year                            Authors  \
# 0  BCI  P300 Spellers  2011  (Y.-T. Wang, Wang, and Jung 2011)
# 1  BCI  P300 Spellers  2012                  (Liu et al. 2012)
# 2  BCI  P300 Spellers  2013             (Duvinage et al. 2013)
# 3  BCI  P300 Spellers  2014               (De Vos et al. 2014)
# 4  BCI  P300 Spellers  2014             (Pinegger et al. 2014)
#
#                                          Details  Nchannels wEEG system  \
# 0                   Brain-Mobile Phone Interface          4    Homemade
# 1                             BCI based on SSVEP         14        EPOC
# 2   Performance comparison for P300 applications         14        EPOC
# 3          Comparison between amplifiers for BCI         14        EPOC
# 4  BCI for writing, reading and answering emails         32  g.Nautilus
#
#   wEEG (with details)  Nparticipants Npatients (details)  \
# 0           Homemade              10                   x
# 1                EPOC              4                   x
# 2      1) ANT 2) EPOC              9                   x
# 3       Modified EPOC             13                   x
# 4          g.Nautilus             10                   x
#
#                                     Task description
# 0  Input a ten digit phone number + ENTER key to ...
# 1              Steady-state visual evoked potentials
# 2                                 P300 spelling task
# 3             P300 spelling task (6x6 letter matrix)
# 4    Web elements translated to letters, P300 matrix

# %% [markdown]
# ## Number of channels
# Number of channels used in the reviewed studies

# %%
FS = 22
plt.style.use('seaborn')

# %%
plt.figure()
ax = plt.axes()

plt.hist(df['Nchannels'], bins=32, density=False, label='Nchannels')

# Add title
plt.title('Number of channels', fontweight='bold',fontsize=FS)

# Add data labels
ax.set_xlabel('Number of channels',fontsize=FS-2)
ax.set_ylabel('Number of studies',fontsize=FS-2)

# Set the ranges to plot of x
ax.set_xlim([0, 70])
ax.set_ylim([0, 35])

# Axis ticks
ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_minor_locator(MultipleLocator(2))
ax.tick_params(which='minor', length=3, color='k', direction='out')
ax.tick_params(which='major', length=5, color='k')

plt.show();

# %% [markdown]
# ## Number of participants
# Number of participants used in the reviewed studies

# %%
# Remove the studies with higher than 500 number of participants
# There's only one, mention it, but the figure otherwise becaomes hard to read
cond = df['Nparticipants']<500

# %%
plt.figure()
ax = plt.axes()

plt.hist(df['Nparticipants'][cond], bins=25)

# Add title
plt.title('Number of participants', fontweight='bold',fontsize=FS)

# Add data labels
ax.set_xlabel('Number of participants',fontsize=FS-2)
ax.set_ylabel('Number of studies',fontsize=FS-2)

# Set the ranges to plot of x
ax.set_xlim([0, 220])
ax.set_ylim([0, 35])

# Axis ticks
ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.tick_params(which='minor', length=3, color='k', direction='out')
ax.tick_params(which='major', length=5, color='k')

plt.show()

# %% [markdown]
# ## Year of the study
# Year when the reviewed studies were published

# %%
plt.figure()
ax = plt.axes()

plt.hist(df['Year'], bins=15, density=False, label='Year')
#sns.distplot(df['Year'], bins=20)

# Add title
plt.title('Number of studies using wEEG', fontweight='bold',fontsize=FS)

# Add data labels
ax.set_xlabel('Year of the study',fontsize=FS-2)
ax.set_ylabel('Number of studies',fontsize=FS-2)

# Set the ranges to plot of x
ax.set_xlim([2005, 2020])
ax.set_ylim([0, 25])

# Axis ticks
ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.tick_params(which='minor', length=3, color='k', direction='out')
ax.tick_params(which='major', length=5, color='k')

plt.show()
